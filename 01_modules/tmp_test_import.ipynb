# %%
import tmp_nice_module

# %%
tmp_nice_module.
# Out:
# array([[ 0.      ,  0.      ],
#        [ 0.204082,  0.209516],
#        [ 0.408163,  0.248883],
#        [ 0.612245,  0.618221],
#        [ 0.816327,  0.597182],
#        [ 1.020408,  1.24208 ],
#        [ 1.22449 ,  0.835374],
#        [ 1.428571,  1.985885],
#        [ 1.632653,  1.656977],
#        [ 1.836735,  1.731347],
#        [ 2.040816,  2.514969],
#        [ 2.244898,  1.392144],
#        [ 2.44898 ,  2.162615],
#        [ 2.653061,  1.873637],
#        [ 2.857143,  1.894688],
#        [ 3.061224,  3.744284],
#        [ 3.265306,  4.468996],
#        [ 3.469388,  2.122912],
#        [ 3.673469,  4.921639],
#        [ 3.877551,  2.712081],
#        [ 4.081633,  4.338455],
#        [ 4.285714,  5.813265],
#        [ 4.489796,  5.86193 ],
#        [ 4.693878,  6.598242],
#        [ 4.897959,  6.346911],
#        [ 5.102041,  5.550386],
#        [ 5.306122,  4.361903],
#        [ 5.510204,  3.906864],
#        [ 5.714286,  5.981882],
#        [ 5.918367,  4.328631],
# ...
